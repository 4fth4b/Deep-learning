# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
haar_data=cv2.CascadeClassifier(cv2.data.haarcascades+ "haarcascade_frontalface_default.xml")

# %%
img=cv2.imread("selfie.jpg")

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=haar_data.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=3)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
cv2.imshow('live',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2=cv2.imread('srk.jpeg')

# %%
gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
edges=cv2.Canny(img2,50,80)

# %%
plt.imshow(edges)
